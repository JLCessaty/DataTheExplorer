# %%
# import dependencies
import psycopg2

import pandas as pd
import csv, os
import scipy.stats as st
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# SQL Alchemy
from sqlalchemy import create_engine

from config import username, password

# %%
df = pd.read_csv ('data/unpopulation_dataportal_20220929172315.csv')
df.head()
# Out:
#    IndicatorId            IndicatorName       IndicatorShortName  \
# 0           49  Total population by sex  Total population by sex
# 1           49  Total population by sex  Total population by sex
# 2           49  Total population by sex  Total population by sex
# 3           49  Total population by sex  Total population by sex
# 4           49  Total population by sex  Total population by sex
#
#                        Source  SourceYear                              Author  \
# 0  World Population Prospects        2022  United Nations Population Division
# 1  World Population Prospects        2022  United Nations Population Division
# 2  World Population Prospects        2022  United Nations Population Division
# 3  World Population Prospects        2022  United Nations Population Division
# 4  World Population Prospects        2022  United Nations Population Division
#
#    LocationId     Location Iso2 Iso3  ...  AgeStart  AgeEnd    Age CategoryId  \
# 0           4  Afghanistan   AF  AFG  ...         0      -1  Total          0
# 1           4  Afghanistan   AF  AFG  ...         0      -1  Total          0
# 2           4  Afghanistan   AF  AFG  ...         0      -1  Total          0
# 3           4  Afghanistan   AF  AFG  ...         0      -1  Total          0
# 4           4  Afghanistan   AF  AFG  ...         0      -1  Total          0
#
#          Category EstimateTypeId           EstimateType  EstimateMethodId  \
# 0  Not applicable              1  Model-based Estimates                 2
# 1  Not applicable              1  Model-based Estimates                 2
# 2  Not applicable              1  Model-based Estimates                 2
# 3  Not applicable              1  Model-based Estimates                 2
# 4  Not applicable              1  Model-based Estimates                 2
#
#    EstimateMethod     Value
# 0   Interpolation  10694796
# 1   Interpolation  10745167
# 2   Interpolation  12057433
# 3   Interpolation  14003760
# 4   Interpolation  15455555
#
# [5 rows x 27 columns]

# %%
dfDropped = df.drop(columns =["Iso2", "IndicatorId","AgeId","Sex","SexId", "Variant", "VariantId","SexId", "IndicatorName", "IndicatorShortName", "Source", "SourceYear", "Author", "TimeId", "AgeStart","AgeEnd", "Age", "CategoryId", "Category", "EstimateTypeId", "EstimateType","EstimateMethodId", "EstimateMethod" ])
dfDropped.head(35)
# Out:
#     LocationId     Location Iso3  Time     Value
# 0            4  Afghanistan  AFG  1990  10694796
# 1            4  Afghanistan  AFG  1991  10745167
# 2            4  Afghanistan  AFG  1992  12057433
# 3            4  Afghanistan  AFG  1993  14003760
# 4            4  Afghanistan  AFG  1994  15455555
# 5            4  Afghanistan  AFG  1995  16418912
# 6            4  Afghanistan  AFG  1996  17106596
# 7            4  Afghanistan  AFG  1997  17788819
# 8            4  Afghanistan  AFG  1998  18493132
# 9            4  Afghanistan  AFG  1999  19262848
# 10           4  Afghanistan  AFG  2000  19542983
# 11           4  Afghanistan  AFG  2001  19688633
# 12           4  Afghanistan  AFG  2002  21000257
# 13           4  Afghanistan  AFG  2003  22645130
# 14           4  Afghanistan  AFG  2004  23553551
# 15           4  Afghanistan  AFG  2005  24411191
# 16           4  Afghanistan  AFG  2006  25442944
# 17           4  Afghanistan  AFG  2007  25903301
# 18           4  Afghanistan  AFG  2008  26427199
# 19           4  Afghanistan  AFG  2009  27385308
# 20           4  Afghanistan  AFG  2010  28189672
# 21           4  Afghanistan  AFG  2011  29249157
# 22           4  Afghanistan  AFG  2012  30466479
# 23           4  Afghanistan  AFG  2013  31541209
# 24           4  Afghanistan  AFG  2014  32716210
# 25           4  Afghanistan  AFG  2015  33753499
# 26           4  Afghanistan  AFG  2016  34636208
# 27           4  Afghanistan  AFG  2017  35643418
# 28           4  Afghanistan  AFG  2018  36686784
# 29           4  Afghanistan  AFG  2019  37769499
# 30           4  Afghanistan  AFG  2020  38972231
# 31           4  Afghanistan  AFG  2021  40099462
# 32           4  Afghanistan  AFG  2022  41128771
# 33           4  Afghanistan  AFG  2023  42239854
# 34           4  Afghanistan  AFG  2024  43372950

# %%
#Extracting data for 1990, 2000, 2010, and 2020
dfYear= dfDropped.loc[(dfDropped["Time"] == 1990) | (dfDropped["Time"] == 2000) | (dfDropped["Time"] == 2010) | (dfDropped["Time"] == 2020)]


dfYear.head(25)
# Out:
#      LocationId             Location Iso3  Time     Value
# 0             4          Afghanistan  AFG  1990  10694796
# 10            4          Afghanistan  AFG  2000  19542983
# 20            4          Afghanistan  AFG  2010  28189672
# 30            4          Afghanistan  AFG  2020  38972231
# 41            8              Albania  ALB  1990   3295066
# 51            8              Albania  ALB  2000   3182021
# 61            8              Albania  ALB  2010   2913400
# 71            8              Albania  ALB  2020   2866849
# 82           12              Algeria  DZA  1990  25518074
# 92           12              Algeria  DZA  2000  30774621
# 102          12              Algeria  DZA  2010  35856344
# 112          12              Algeria  DZA  2020  43451666
# 123          16       American Samoa  ASM  1990     47818
# 133          16       American Samoa  ASM  2000     58230
# 143          16       American Samoa  ASM  2010     54850
# 153          16       American Samoa  ASM  2020     46189
# 164          20              Andorra  AND  1990     53570
# 174          20              Andorra  AND  2000     66098
# 184          20              Andorra  AND  2010     71520
# 194          20              Andorra  AND  2020     77700
# 205          24               Angola  AGO  1990  11828638
# 215          24               Angola  AGO  2000  16394062
# 225          24               Angola  AGO  2010  23364186
# 235          24               Angola  AGO  2020  33428486
# 246          28  Antigua and Barbuda  ATG  1990     63328

# %%
# Renaming the columns
dfYear = dfYear.rename(columns={
'LocationId': 'locationid',
'Location': 'location',
'Iso3': 'iso3',
'Time': 'time',
'Value': 'population'
})

# %%
dfYear
# Out:
#       locationid     location iso3  time  population
# 0              4  Afghanistan  AFG  1990    10694796
# 10             4  Afghanistan  AFG  2000    19542983
# 20             4  Afghanistan  AFG  2010    28189672
# 30             4  Afghanistan  AFG  2020    38972231
# 41             8      Albania  ALB  1990     3295066
# ...          ...          ...  ...   ...         ...
# 9624         887        Yemen  YEM  2020    32284046
# 9635         894       Zambia  ZMB  1990     7686401
# 9645         894       Zambia  ZMB  2000     9891136
# 9655         894       Zambia  ZMB  2010    13792087
# 9665         894       Zambia  ZMB  2020    18927715
#
# [944 rows x 5 columns]

# %%
# Creating CSV file - populations.csv
dfYear.to_csv ('data/populations.csv', index = None)

# %%
#Read locations.csv into a dataframe
locationDF = pd.read_csv ('data/locations.csv')
df.head()
# Out:
#    IndicatorId            IndicatorName       IndicatorShortName  \
# 0           49  Total population by sex  Total population by sex
# 1           49  Total population by sex  Total population by sex
# 2           49  Total population by sex  Total population by sex
# 3           49  Total population by sex  Total population by sex
# 4           49  Total population by sex  Total population by sex
#
#                        Source  SourceYear                              Author  \
# 0  World Population Prospects        2022  United Nations Population Division
# 1  World Population Prospects        2022  United Nations Population Division
# 2  World Population Prospects        2022  United Nations Population Division
# 3  World Population Prospects        2022  United Nations Population Division
# 4  World Population Prospects        2022  United Nations Population Division
#
#    LocationId     Location Iso2 Iso3  ...  AgeStart  AgeEnd    Age CategoryId  \
# 0           4  Afghanistan   AF  AFG  ...         0      -1  Total          0
# 1           4  Afghanistan   AF  AFG  ...         0      -1  Total          0
# 2           4  Afghanistan   AF  AFG  ...         0      -1  Total          0
# 3           4  Afghanistan   AF  AFG  ...         0      -1  Total          0
# 4           4  Afghanistan   AF  AFG  ...         0      -1  Total          0
#
#          Category EstimateTypeId           EstimateType  EstimateMethodId  \
# 0  Not applicable              1  Model-based Estimates                 2
# 1  Not applicable              1  Model-based Estimates                 2
# 2  Not applicable              1  Model-based Estimates                 2
# 3  Not applicable              1  Model-based Estimates                 2
# 4  Not applicable              1  Model-based Estimates                 2
#
#    EstimateMethod     Value
# 0   Interpolation  10694796
# 1   Interpolation  10745167
# 2   Interpolation  12057433
# 3   Interpolation  14003760
# 4   Interpolation  15455555
#
# [5 rows x 27 columns]

# %%
#Read gdp.csv into a dataframe
gdpDF = pd.read_csv ('data/ungdpdata.csv')
gdpDF.head()
# Out:
#    Country or Area Code Country or Area  Year                          Item  \
# 0                     4     Afghanistan  2020  Gross Domestic Product (GDP)
# 1                     4     Afghanistan  2019  Gross Domestic Product (GDP)
# 2                     4     Afghanistan  2018  Gross Domestic Product (GDP)
# 3                     4     Afghanistan  2017  Gross Domestic Product (GDP)
# 4                     4     Afghanistan  2016  Gross Domestic Product (GDP)
#
#         Value
# 0  508.453722
# 1  496.940553
# 2  495.504343
# 3  520.616409
# 4  509.271172

# %%
# Renaming the columns
gdpDF = gdpDF.rename(columns={
'Country or Area Code': 'locationid',
'Country or Area': 'country',
'Year': 'year',
'Item': 'item',
'Value': 'gdp'
})

# %%
# Renaming the columns
gdpDF
# Out:
#        locationid      country  year                          item         gdp
# 0               4  Afghanistan  2020  Gross Domestic Product (GDP)  508.453722
# 1               4  Afghanistan  2019  Gross Domestic Product (GDP)  496.940553
# 2               4  Afghanistan  2018  Gross Domestic Product (GDP)  495.504343
# 3               4  Afghanistan  2017  Gross Domestic Product (GDP)  520.616409
# 4               4  Afghanistan  2016  Gross Domestic Product (GDP)  509.271172
# ...           ...          ...   ...                           ...         ...
# 10289         716     Zimbabwe  1974  Gross Domestic Product (GDP)  811.510083
# 10290         716     Zimbabwe  1973  Gross Domestic Product (GDP)  698.192005
# 10291         716     Zimbabwe  1972  Gross Domestic Product (GDP)  588.037380
# 10292         716     Zimbabwe  1971  Gross Domestic Product (GDP)  493.287110
# 10293         716     Zimbabwe  1970  Gross Domestic Product (GDP)  441.744085
#
# [10294 rows x 5 columns]

# %%
# Create Engine for project3 data
engine = create_engine(f"postgresql://{username}:{password}@localhost/worldPopulation")

conn = engine.connect()
#uploading to respecive tables in project2 database

dfYear.to_sql('populations', con=conn, if_exists='replace', index=False)
locationDF.to_sql('locations', con=conn, if_exists='replace', index=False)
gdpDF.to_sql('gdp', con=conn, if_exists='replace', index=False)
# Out:
# 294

# %%
#Read worldPopulationData.csv into a dataframe
worldPopulationsDataDF = pd.read_csv ('data/worldPopulationsData.csv')
worldPopulationsDataDF.head()
# Out:
#    locationid     location iso3  time  population         gdp  longitude  \
# 0           4  Afghanistan  AFG  1990    10694796  286.772753  67.709953
# 1           4  Afghanistan  AFG  2000    19542983  160.829727  67.709953
# 2           4  Afghanistan  AFG  2010    28189672  503.636606  67.709953
# 3           4  Afghanistan  AFG  2020    38972231  508.453722  67.709953
# 4           8      Albania  ALB  1990     3295066  652.983427  20.168331
#
#     latitude
# 0  33.939110
# 1  33.939110
# 2  33.939110
# 3  33.939110
# 4  41.153332

# %%
len(worldPopulationsDataDF)
# Out:
# 828

# %%
worldPopulationsDataDF = worldPopulationsDataDF.sort_values(by =['location', 'time'], ascending=[True, False], na_position = 'first')
worldPopulationsDataDF

#df.sort_values(by = ['Rank', 'Age'], ascending = [True, False], na_position = 'first')
# Out:
#      locationid     location iso3  time  population          gdp  longitude  \
# 3             4  Afghanistan  AFG  2020    38972231   508.453722  67.709953
# 2             4  Afghanistan  AFG  2010    28189672   503.636606  67.709953
# 1             4  Afghanistan  AFG  2000    19542983   160.829727  67.709953
# 0             4  Afghanistan  AFG  1990    10694796   286.772753  67.709953
# 7             8      Albania  ALB  2020     2866849  5180.914198  20.168331
# ..          ...          ...  ...   ...         ...          ...        ...
# 824         894       Zambia  ZMB  1990     7686401   472.176634  27.849333
# 703         716     Zimbabwe  ZWE  2020    15669666  1465.845054  29.154858
# 702         716     Zimbabwe  ZWE  2010    12839771   948.331853  29.154858
# 701         716     Zimbabwe  ZWE  2000    11834677   733.958861  29.154858
# 700         716     Zimbabwe  ZWE  1990    10113893  1299.806761  29.154858
#
#       latitude
# 3    33.939110
# 2    33.939110
# 1    33.939110
# 0    33.939110
# 7    41.153332
# ..         ...
# 824 -13.133897
# 703 -19.015438
# 702 -19.015438
# 701 -19.015438
# 700 -19.015438
#
# [828 rows x 8 columns]

# %%
# Calculate population growth
changeList = []

for i in range(len(worldPopulationsDataDF) - 1):
    
    if worldPopulationsDataDF.loc[i, "location"] == worldPopulationsDataDF.loc[i+1, "location"]:
        change = ((worldPopulationsDataDF.loc[i, "population"] - worldPopulationsDataDF.loc[i + 1, "population"])/worldPopulationsDataDF.loc[i + 1, "population"])
        changeList.append(change)
        
    else:
        change = 0
        changeList.append(change)
             



changeList.insert(780, 0)
#print(changeList)
worldPopulationsDataDF["popGrowth"] = changeList
worldPopulationsDataDF.tail
# Out:
# <bound method NDFrame.tail of      locationid     location iso3  time  population          gdp  longitude  \
# 3             4  Afghanistan  AFG  2020    38972231   508.453722  67.709953
# 2             4  Afghanistan  AFG  2010    28189672   503.636606  67.709953
# 1             4  Afghanistan  AFG  2000    19542983   160.829727  67.709953
# 0             4  Afghanistan  AFG  1990    10694796   286.772753  67.709953
# 7             8      Albania  ALB  2020     2866849  5180.914198  20.168331
# ..          ...          ...  ...   ...         ...          ...        ...
# 824         894       Zambia  ZMB  1990     7686401   472.176634  27.849333
# 703         716     Zimbabwe  ZWE  2020    15669666  1465.845054  29.154858
# 702         716     Zimbabwe  ZWE  2010    12839771   948.331853  29.154858
# 701         716     Zimbabwe  ZWE  2000    11834677   733.958861  29.154858
# 700         716     Zimbabwe  ZWE  1990    10113893  1299.806761  29.154858
#
#       latitude  popGrowth
# 3    33.939110  -0.452755
# 2    33.939110  -0.306733
# 1    33.939110  -0.276673
# 0    33.939110   0.000000
# 7    41.153332   0.035526
# ..         ...        ...
# 824 -13.133897  -0.233555
# 703 -19.015438   0.000000
# 702 -19.015438  -0.222900
# 701 -19.015438  -0.282840
# 700 -19.015438  -0.271328
#
# [828 rows x 9 columns]>

# %%
# Calculate GDP growth
changegdplist = []

for i in range(len(worldPopulationsDataDF) - 1):
    
    if worldPopulationsDataDF.loc[i, "location"] == worldPopulationsDataDF.loc[i+1, "location"]:
        changegdp = ((worldPopulationsDataDF.loc[i, "gdp"] - worldPopulationsDataDF.loc[i + 1, "gdp"])/worldPopulationsDataDF.loc[i + 1, "gdp"])
        changegdplist.append(changegdp)
        
    else:
        changegdp = 0
        changegdplist.append(changegdp)
        
changegdplist.insert(780, 0)
#print(changeList)
worldPopulationsDataDF["gdpGrowth"] = changegdplist
worldPopulationsDataDF.tail
# Out:
# <bound method NDFrame.tail of      locationid     location iso3  time  population          gdp  longitude  \
# 3             4  Afghanistan  AFG  2020    38972231   508.453722  67.709953
# 2             4  Afghanistan  AFG  2010    28189672   503.636606  67.709953
# 1             4  Afghanistan  AFG  2000    19542983   160.829727  67.709953
# 0             4  Afghanistan  AFG  1990    10694796   286.772753  67.709953
# 7             8      Albania  ALB  2020     2866849  5180.914198  20.168331
# ..          ...          ...  ...   ...         ...          ...        ...
# 824         894       Zambia  ZMB  1990     7686401   472.176634  27.849333
# 703         716     Zimbabwe  ZWE  2020    15669666  1465.845054  29.154858
# 702         716     Zimbabwe  ZWE  2010    12839771   948.331853  29.154858
# 701         716     Zimbabwe  ZWE  2000    11834677   733.958861  29.154858
# 700         716     Zimbabwe  ZWE  1990    10113893  1299.806761  29.154858
#
#       latitude  popGrowth  gdpGrowth
# 3    33.939110  -0.452755   0.783083
# 2    33.939110  -0.306733  -0.680663
# 1    33.939110  -0.276673  -0.009474
# 0    33.939110   0.000000   0.000000
# 7    41.153332   0.035526  -0.414109
# ..         ...        ...        ...
# 824 -13.133897  -0.233555   0.423949
# 703 -19.015438   0.000000   0.000000
# 702 -19.015438  -0.222900   0.365918
# 701 -19.015438  -0.282840  -0.767911
# 700 -19.015438  -0.271328   0.511926
#
# [828 rows x 10 columns]>

# %%
worldPopulationsDataDF.to_csv ('data/worldgdppop.csv', index = None)

# %%
worldDF = pd.read_csv ('data/worldgdppop.csv')
worldDF .head()
# Out:
#    locationid     location iso3  time  population          gdp  longitude  \
# 0           4  Afghanistan  AFG  2020    38972231   508.453722  67.709953
# 1           4  Afghanistan  AFG  2010    28189672   503.636606  67.709953
# 2           4  Afghanistan  AFG  2000    19542983   160.829727  67.709953
# 3           4  Afghanistan  AFG  1990    10694796   286.772753  67.709953
# 4           8      Albania  ALB  2020     2866849  5180.914198  20.168331
#
#     latitude  popGrowth  gdpGrowth
# 0  33.939110  -0.452755   0.783083
# 1  33.939110  -0.306733  -0.680663
# 2  33.939110  -0.276673  -0.009474
# 3  33.939110   0.000000   0.000000
# 4  41.153332   0.035526  -0.414109

# %%
year2020DF = worldDF[worldDF["time"]== 2020]
year2020DF = year2020DF.set_index('location')

year2010DF = worldDF[worldDF["time"]== 2010]
year2010DF = year2010DF.set_index('location')
year2000DF = worldDF[worldDF["time"]== 2000]
year2000DF = year2000DF.set_index('location')
year1990DF = worldDF[worldDF["time"]== 1990]
year1990DF = year1990DF.set_index('location')

year2020DF.head(10)
# Out:
#                      locationid iso3  time  population           gdp  \
# location
# Afghanistan                   4  AFG  2020    38972231    508.453722
# Albania                       8  ALB  2020     2866849   5180.914198
# Algeria                      12  DZA  2020    43451666   3367.963003
# Andorra                      20  AND  2020       77700  37072.405384
# Angola                       24  AGO  2020    33428486   1895.770703
# Anguilla                    660  AIA  2020       15585  17225.937529
# Antigua and Barbuda          28  ATG  2020       92664  13993.320179
# Argentina                    32  ARG  2020    45036032   8475.729582
# Armenia                      51  ARM  2020     2805609   4266.005479
# Aruba                       533  ABW  2020      106585  23385.638671
#
#                      longitude   latitude  popGrowth  gdpGrowth
# location
# Afghanistan          67.709953  33.939110  -0.452755   0.783083
# Albania              20.168331  41.153332   0.035526  -0.414109
# Algeria               1.659626  28.033886  -0.170808   0.361283
# Andorra               1.521801  42.506287  -0.189537   0.092975
# Angola               17.873886 -11.202692  -0.278480   0.548648
# Anguilla            -63.068615  18.220554  -0.156245  -0.287373
# Antigua and Barbuda -61.789180  17.078670  -0.093098   0.386393
# Argentina           -63.616673 -38.416096  -0.119585  -0.438079
# Armenia              45.038189  40.069099  -0.103584  -0.113716
# Aruba               -69.968338  12.521110  -0.041409  -0.116307

# %%
year2020Pop = year2020DF["population"]
year2010Pop = year2010DF["population"]
year2000Pop = year2000DF["population"]
year1990Pop = year1990DF["population"]

# Combine series into single DataFrame
PopByDecade = pd.DataFrame({
    "1990" : year1990Pop,
    "2000" : year2000Pop,
    "2010" : year2010Pop,
    "2020" : year2020Pop
 })
PopByDecade.head()
# Out:
#                    1990        2000      2010      2020
# location
# Afghanistan  10694796.0  19542983.0  28189672  38972231
# Albania       3295066.0   3182021.0   2913400   2866849
# Algeria      25518074.0  30774621.0  35856344  43451666
# Andorra         53570.0     66098.0     71520     77700
# Angola       11828638.0  16394062.0  23364186  33428486

# %%
#PopByDecade.reset_index(inplace=True)

PopByDecade = PopByDecade.sort_values(by='2020', ascending=False)

PopByDecade
# Out:
#                                   1990          2000        2010        2020
# location
# China                     1.153704e+09  1.264099e+09  1348191368  1424929781
# India                     8.704522e+08  1.059634e+09  1240613620  1396387127
# United States of America  2.480837e+08  2.823986e+08   311182845   335942004
# Indonesia                 1.821599e+08  2.140724e+08   244016173   271857971
# Pakistan                  1.154141e+08  1.543699e+08   194454498   227196741
# ...                                ...           ...         ...         ...
# Cook Islands              1.712300e+04  1.589700e+04       17212       17029
# Anguilla                  8.316000e+03  1.104800e+04       13172       15585
# Nauru                     9.598000e+03  1.037700e+04       10241       12315
# Tuvalu                    9.183000e+03  9.638000e+03       10550       11069
# Montserrat                1.080500e+04  5.138000e+03        4938        4500
#
# [209 rows x 4 columns]

# %%
PopByDecade = PopByDecade.reset_index()
PopByDecade
# Out:
#                      location          1990          2000        2010  \
# 0                       China  1.153704e+09  1.264099e+09  1348191368
# 1                       India  8.704522e+08  1.059634e+09  1240613620
# 2    United States of America  2.480837e+08  2.823986e+08   311182845
# 3                   Indonesia  1.821599e+08  2.140724e+08   244016173
# 4                    Pakistan  1.154141e+08  1.543699e+08   194454498
# ..                        ...           ...           ...         ...
# 204              Cook Islands  1.712300e+04  1.589700e+04       17212
# 205                  Anguilla  8.316000e+03  1.104800e+04       13172
# 206                     Nauru  9.598000e+03  1.037700e+04       10241
# 207                    Tuvalu  9.183000e+03  9.638000e+03       10550
# 208                Montserrat  1.080500e+04  5.138000e+03        4938
#
#            2020
# 0    1424929781
# 1    1396387127
# 2     335942004
# 3     271857971
# 4     227196741
# ..          ...
# 204       17029
# 205       15585
# 206       12315
# 207       11069
# 208        4500
#
# [209 rows x 5 columns]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
import matplotlib.pyplot as plt

x_axis = PopByDecade["location"][0:20]
y_axis = PopByDecade["2020"][0:20]

x_axis_length = np.arange(len(PopByDecade["location"][0:20]))
tick_locations = [value for value in x_axis_length]

#print(x_axis)
#print(y_axis)
#print(tick_locations)

plt.figure(figsize=(20,6))
plt.bar(x_axis, y_axis, color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, x_axis, rotation="vertical")
plt.title("Top 20 Countries - 2020 Population")
plt.xlabel("Countries")
plt.ylabel("2020 Population")

plt.show()
plt.tight_layout()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for population and gdp for the countries
population = year2020DF.iloc[:,4]
gdp = year2020DF.iloc[:,5]
correlation = st.pearsonr(population,gdp)

print(f"The correlation between Country population and the gdp is {round(correlation[0],2)}")
# Out:
# The correlation between Country population and the gdp is -0.07

# %%
# Add the linear regression equation and line to plot

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(population,gdp)
regress_values = population * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(population,gdp)
plt.plot(population,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.title("Country Population Vs GDP")
plt.xlabel('Population')
plt.ylabel('GDP')

#plt.savefig("images/regression_plot.png")
plt.show()
